# %%
import os
import tensorflow            as tf
import numpy                 as np
import matplotlib.pyplot     as plt
import tensorflow_datasets   as tfds
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Lambda, Dropout

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-PCIE-40GB (UUID: GPU-f9b3d719-9ffe-0dab-1700-db0fab379a6f)

# %%
(train_set, val_set), info = tfds.load('cats_vs_dogs',
                                        split         = ['train[:80%]', 'train[80%:]'],
                                        as_supervised = True,
                                        with_info     = True)
# Out:
# 2024-11-02 12:42:41.218300: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
IMG_SIZE   = (224,224)
BATCH_SIZE = 256

# %%
def preprocess_image(image, label):
    image  = tf.image.resize(image, IMG_SIZE)
    image  = tf.cast(image, tf.float32) / 255.0
    return image, label

# %%
training_set   = train_set.map(preprocess_image, num_parallel_calls = tf.data.AUTOTUNE)
training_set   = training_set.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

validation_set = val_set.map(preprocess_image, num_parallel_calls = tf.data.AUTOTUNE)
validation_set = validation_set.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
val_size       = int(0.4 * len(validation_set))
test_set       = validation_set.take(val_size)
validation_set = validation_set.skip(val_size)

# %%
images, labels = next(iter(training_set))

image = images[0]
print(f'Image Shape: {image.shape}\nImage dtype: {image.dtype}\nMax pixel value: {np.max(image)}')
# Out:
# Image Shape: (224, 224, 3)
# Image dtype: <dtype: 'float32'>
# Max pixel value: 1.0

# %%
import random
from tensorflow.keras.metrics      import Precision, Recall, AUC
from tensorflow.keras.backend      import epsilon
from tensorflow.keras.regularizers import l2

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name="f1_score", **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + tf.keras.backend.epsilon()))

    def reset_states(self):
        self.precision.reset_state()
        self.recall.reset_state()

# %%
def set_random_seeds(seed_value):
    np.random.seed(seed_value)
    random.seed(seed_value)
    tf.random.set_seed(seed_value)

# %%
def create_model():
    base_model = tf.keras.applications.DenseNet121(include_top = False,
                                                   input_shape = (224,224,3),
                                                   weights     = 'imagenet',)
    base_model.trainable = False

    x       = base_model.output
    x       = GlobalAveragePooling2D()(x)
    x       = Dropout(0.2)(x)
    x       = Dense(512,
                    activation         ='relu',
                    kernel_regularizer = l2(0.001))(x)
    x       = Dropout(0.4)(x)
    outputs = Dense(1,
                    activation         ='sigmoid',
                    kernel_regularizer = l2(0.001))(x)

    model   = tf.keras.Model(inputs = base_model.input, outputs=outputs)
    
    
    model.compile(optimizer = tf.keras.optimizers.Adam(),
                 loss       = 'binary_crossentropy',
                 metrics    = ['accuracy',
                         Precision(name = 'precision'),
                         Recall(name    = 'recall'),
                         AUC(name       = 'auc'),
                         F1Score(name   = 'f1_score')])
    return model

# %%
num_trials  = 10
results     = []

# Create directory if it doesn't exist
save_dir    = "models/diff_seeds"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for i in range(num_trials):
    print(f"Trial {i+1}")
    seed    = i  # Different seed for each trial
    set_random_seeds(seed)

    model   = create_model()
    
    history = model.fit(training_set, validation_data=validation_set, epochs=10, verbose=2)

    val_acc = history.history['val_accuracy'][1]
    print(f"Validation Accuracy for trial {i+1}: {val_acc}")
    
    results.append({
        'trial'   : i+1,
        'seed'    : seed,
        'val_acc' : val_acc,
        'history' : history.history
    })

    test_loss, test_acc, _, _, _, _ = model.evaluate(test_set)
    print(f"Test Accuracy for trial {i+1}: {test_acc}")
    
    model_name = f'DenseNet{i+1}.h5'
    model_path = os.path.join(save_dir, model_name)

    # Save the model if both validation and test accuracy are greater than 0.95
    if val_acc > 0.95 and test_acc > 0.95:
        model.save(model_path)
        print(f"Model saved as {model_path}")
# Out:
# Trial 1
# Epoch 1/10
# 73/73 - 74s - loss: 0.5077 - accuracy: 0.9546 - precision: 0.9516 - recall: 0.9571 - auc: 0.9927 - f1_score: 0.9544 - val_loss: 0.3065 - val_accuracy: 0.9843 - val_precision: 0.9861 - val_recall: 0.9827 - val_auc: 0.9989 - val_f1_score: 0.9844 - 74s/epoch - 1s/step
# Epoch 2/10
# 73/73 - 67s - loss: 0.2707 - accuracy: 0.9809 - precision: 0.9807 - recall: 0.9807 - auc: 0.9980 - f1_score: 0.9807 - val_loss: 0.2375 - val_accuracy: 0.9780 - val_precision: 0.9915 - val_recall: 0.9647 - val_auc: 0.9990 - val_f1_score: 0.9779 - 67s/epoch - 916ms/step
# Epoch 3/10
# 73/73 - 67s - loss: 0.2058 - accuracy: 0.9833 - precision: 0.9830 - recall: 0.9834 - auc: 0.9984 - f1_score: 0.9832 - val_loss: 0.1844 - val_accuracy: 0.9822 - val_precision: 0.9901 - val_recall: 0.9744 - val_auc: 0.9991 - val_f1_score: 0.9822 - 67s/epoch - 911ms/step
# Epoch 4/10
# 73/73 - 67s - loss: 0.1677 - accuracy: 0.9839 - precision: 0.9830 - recall: 0.9845 - auc: 0.9984 - f1_score: 0.9838 - val_loss: 0.1587 - val_accuracy: 0.9811 - val_precision: 0.9943 - val_recall: 0.9681 - val_auc: 0.9991 - val_f1_score: 0.9811 - 67s/epoch - 917ms/step
# Epoch 5/10
# 73/73 - 68s - loss: 0.1394 - accuracy: 0.9840 - precision: 0.9830 - recall: 0.9847 - auc: 0.9985 - f1_score: 0.9839 - val_loss: 0.1255 - val_accuracy: 0.9825 - val_precision: 0.9908 - val_recall: 0.9744 - val_auc: 0.9992 - val_f1_score: 0.9825 - 68s/epoch - 934ms/step
# Epoch 6/10
# 73/73 - 66s - loss: 0.1171 - accuracy: 0.9842 - precision: 0.9833 - recall: 0.9848 - auc: 0.9989 - f1_score: 0.9841 - val_loss: 0.1165 - val_accuracy: 0.9804 - val_precision: 0.9936 - val_recall: 0.9675 - val_auc: 0.9992 - val_f1_score: 0.9804 - 66s/epoch - 907ms/step
# Epoch 7/10
# 73/73 - 67s - loss: 0.1050 - accuracy: 0.9832 - precision: 0.9817 - recall: 0.9844 - auc: 0.9986 - f1_score: 0.9831 - val_loss: 0.1021 - val_accuracy: 0.9822 - val_precision: 0.9929 - val_recall: 0.9716 - val_auc: 0.9992 - val_f1_score: 0.9821 - 67s/epoch - 915ms/step
# Epoch 8/10
# 73/73 - 66s - loss: 0.0938 - accuracy: 0.9842 - precision: 0.9834 - recall: 0.9847 - auc: 0.9987 - f1_score: 0.9841 - val_loss: 0.0927 - val_accuracy: 0.9818 - val_precision: 0.9915 - val_recall: 0.9723 - val_auc: 0.9992 - val_f1_score: 0.9818 - 66s/epoch - 910ms/step
# Epoch 9/10
# 73/73 - 66s - loss: 0.0821 - accuracy: 0.9853 - precision: 0.9851 - recall: 0.9853 - auc: 0.9988 - f1_score: 0.9852 - val_loss: 0.0800 - val_accuracy: 0.9832 - val_precision: 0.9895 - val_recall: 0.9771 - val_auc: 0.9992 - val_f1_score: 0.9833 - 66s/epoch - 909ms/step
# Epoch 10/10
# 73/73 - 67s - loss: 0.0748 - accuracy: 0.9852 - precision: 0.9847 - recall: 0.9854 - auc: 0.9989 - f1_score: 0.9851 - val_loss: 0.0775 - val_accuracy: 0.9829 - val_precision: 0.9936 - val_recall: 0.9723 - val_auc: 0.9993 - val_f1_score: 0.9828 - 67s/epoch - 913ms/step
# Validation Accuracy for trial 1: 0.9779720306396484
# 7/7 [==============================] - 6s 783ms/step - loss: 0.0700 - accuracy: 0.9888 - precision: 0.9956 - recall: 0.9828 - auc: 0.9985 - f1_score: 0.9892
# Test Accuracy for trial 1: 0.9888392686843872
# /opt/conda/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved as models/diff_seeds/DenseNet1.h5
# Trial 2
# Epoch 1/10
# 73/73 - 73s - loss: 0.5461 - accuracy: 0.9462 - precision: 0.9436 - recall: 0.9481 - auc: 0.9899 - f1_score: 0.9459 - val_loss: 0.3271 - val_accuracy: 0.9815 - val_precision: 0.9827 - val_recall: 0.9806 - val_auc: 0.9987 - val_f1_score: 0.9816 - 73s/epoch - 1s/step
# Epoch 2/10
# 73/73 - 67s - loss: 0.2907 - accuracy: 0.9821 - precision: 0.9816 - recall: 0.9822 - auc: 0.9984 - f1_score: 0.9819 - val_loss: 0.2497 - val_accuracy: 0.9832 - val_precision: 0.9854 - val_recall: 0.9813 - val_auc: 0.9990 - val_f1_score: 0.9833 - 67s/epoch - 919ms/step
# Epoch 3/10
# 73/73 - 66s - loss: 0.2311 - accuracy: 0.9821 - precision: 0.9823 - recall: 0.9816 - auc: 0.9982 - f1_score: 0.9820 - val_loss: 0.2077 - val_accuracy: 0.9804 - val_precision: 0.9922 - val_recall: 0.9688 - val_auc: 0.9991 - val_f1_score: 0.9804 - 66s/epoch - 906ms/step
# Epoch 4/10
# 73/73 - 66s - loss: 0.1849 - accuracy: 0.9846 - precision: 0.9847 - recall: 0.9843 - auc: 0.9986 - f1_score: 0.9845 - val_loss: 0.1731 - val_accuracy: 0.9808 - val_precision: 0.9929 - val_recall: 0.9688 - val_auc: 0.9992 - val_f1_score: 0.9807 - 66s/epoch - 901ms/step
# Epoch 5/10
# 73/73 - 66s - loss: 0.1531 - accuracy: 0.9852 - precision: 0.9859 - recall: 0.9842 - auc: 0.9987 - f1_score: 0.9850 - val_loss: 0.1422 - val_accuracy: 0.9836 - val_precision: 0.9909 - val_recall: 0.9765 - val_auc: 0.9992 - val_f1_score: 0.9836 - 66s/epoch - 905ms/step
# Epoch 6/10
# 73/73 - 66s - loss: 0.1329 - accuracy: 0.9844 - precision: 0.9851 - recall: 0.9833 - auc: 0.9988 - f1_score: 0.9842 - val_loss: 0.1231 - val_accuracy: 0.9839 - val_precision: 0.9895 - val_recall: 0.9785 - val_auc: 0.9992 - val_f1_score: 0.9840 - 66s/epoch - 902ms/step
# Epoch 7/10
# 73/73 - 66s - loss: 0.1177 - accuracy: 0.9838 - precision: 0.9833 - recall: 0.9841 - auc: 0.9986 - f1_score: 0.9837 - val_loss: 0.1115 - val_accuracy: 0.9822 - val_precision: 0.9915 - val_recall: 0.9730 - val_auc: 0.9992 - val_f1_score: 0.9822 - 66s/epoch - 907ms/step
# Epoch 8/10
# 73/73 - 66s - loss: 0.1038 - accuracy: 0.9840 - precision: 0.9830 - recall: 0.9848 - auc: 0.9987 - f1_score: 0.9839 - val_loss: 0.1112 - val_accuracy: 0.9783 - val_precision: 0.9957 - val_recall: 0.9612 - val_auc: 0.9993 - val_f1_score: 0.9782 - 66s/epoch - 904ms/step
# Epoch 9/10
# 73/73 - 66s - loss: 0.0912 - accuracy: 0.9850 - precision: 0.9841 - recall: 0.9857 - auc: 0.9989 - f1_score: 0.9849 - val_loss: 0.0909 - val_accuracy: 0.9825 - val_precision: 0.9915 - val_recall: 0.9737 - val_auc: 0.9992 - val_f1_score: 0.9825 - 66s/epoch - 907ms/step
# Epoch 10/10
# 73/73 - 66s - loss: 0.0827 - accuracy: 0.9857 - precision: 0.9855 - recall: 0.9857 - auc: 0.9989 - f1_score: 0.9856 - val_loss: 0.0840 - val_accuracy: 0.9818 - val_precision: 0.9915 - val_recall: 0.9723 - val_auc: 0.9992 - val_f1_score: 0.9818 - 66s/epoch - 910ms/step
# Validation Accuracy for trial 2: 0.9832167625427246
# 7/7 [==============================] - 6s 836ms/step - loss: 0.0735 - accuracy: 0.9877 - precision: 0.9935 - recall: 0.9828 - auc: 0.9985 - f1_score: 0.9881
# Test Accuracy for trial 2: 0.9877232313156128
# Model saved as models/diff_seeds/DenseNet2.h5
# Trial 3
# Epoch 1/10
# 73/73 - 73s - loss: 0.4620 - accuracy: 0.9672 - precision: 0.9652 - recall: 0.9687 - auc: 0.9952 - f1_score: 0.9670 - val_loss: 0.2827 - val_accuracy: 0.9783 - val_precision: 0.9901 - val_recall: 0.9668 - val_auc: 0.9989 - val_f1_score: 0.9783 - 73s/epoch - 1s/step
# Epoch 2/10
# 73/73 - 67s - loss: 0.2366 - accuracy: 0.9818 - precision: 0.9814 - recall: 0.9819 - auc: 0.9981 - f1_score: 0.9816 - val_loss: 0.1933 - val_accuracy: 0.9836 - val_precision: 0.9854 - val_recall: 0.9820 - val_auc: 0.9990 - val_f1_score: 0.9837 - 67s/epoch - 913ms/step
# Epoch 3/10
# 73/73 - 67s - loss: 0.1750 - accuracy: 0.9816 - precision: 0.9816 - recall: 0.9813 - auc: 0.9982 - f1_score: 0.9814 - val_loss: 0.1506 - val_accuracy: 0.9815 - val_precision: 0.9908 - val_recall: 0.9723 - val_auc: 0.9992 - val_f1_score: 0.9815 - 67s/epoch - 916ms/step
# Epoch 4/10
# 73/73 - 66s - loss: 0.1409 - accuracy: 0.9818 - precision: 0.9815 - recall: 0.9819 - auc: 0.9984 - f1_score: 0.9817 - val_loss: 0.1196 - val_accuracy: 0.9850 - val_precision: 0.9875 - val_recall: 0.9827 - val_auc: 0.9992 - val_f1_score: 0.9851 - 66s/epoch - 904ms/step
# Epoch 5/10
# 73/73 - 67s - loss: 0.1186 - accuracy: 0.9811 - precision: 0.9806 - recall: 0.9814 - auc: 0.9983 - f1_score: 0.9810 - val_loss: 0.1032 - val_accuracy: 0.9843 - val_precision: 0.9895 - val_recall: 0.9792 - val_auc: 0.9992 - val_f1_score: 0.9843 - 67s/epoch - 916ms/step
# Epoch 6/10
# 73/73 - 67s - loss: 0.0976 - accuracy: 0.9840 - precision: 0.9837 - recall: 0.9842 - auc: 0.9987 - f1_score: 0.9839 - val_loss: 0.1006 - val_accuracy: 0.9801 - val_precision: 0.9943 - val_recall: 0.9661 - val_auc: 0.9993 - val_f1_score: 0.9800 - 67s/epoch - 918ms/step
# Epoch 7/10
# 73/73 - 67s - loss: 0.0874 - accuracy: 0.9840 - precision: 0.9841 - recall: 0.9838 - auc: 0.9987 - f1_score: 0.9839 - val_loss: 0.0813 - val_accuracy: 0.9839 - val_precision: 0.9888 - val_recall: 0.9792 - val_auc: 0.9992 - val_f1_score: 0.9840 - 67s/epoch - 919ms/step
# Epoch 8/10
# 73/73 - 66s - loss: 0.0769 - accuracy: 0.9848 - precision: 0.9842 - recall: 0.9852 - auc: 0.9988 - f1_score: 0.9847 - val_loss: 0.0727 - val_accuracy: 0.9850 - val_precision: 0.9909 - val_recall: 0.9792 - val_auc: 0.9993 - val_f1_score: 0.9850 - 66s/epoch - 911ms/step
# Epoch 9/10
# 73/73 - 67s - loss: 0.0700 - accuracy: 0.9845 - precision: 0.9842 - recall: 0.9846 - auc: 0.9989 - f1_score: 0.9844 - val_loss: 0.0699 - val_accuracy: 0.9843 - val_precision: 0.9909 - val_recall: 0.9778 - val_auc: 0.9992 - val_f1_score: 0.9843 - 67s/epoch - 913ms/step
# Epoch 10/10
# 73/73 - 66s - loss: 0.0671 - accuracy: 0.9854 - precision: 0.9856 - recall: 0.9851 - auc: 0.9989 - f1_score: 0.9853 - val_loss: 0.0643 - val_accuracy: 0.9839 - val_precision: 0.9827 - val_recall: 0.9855 - val_auc: 0.9992 - val_f1_score: 0.9841 - 66s/epoch - 910ms/step
# Validation Accuracy for trial 3: 0.9835664629936218
# 7/7 [==============================] - 6s 778ms/step - loss: 0.0554 - accuracy: 0.9922 - precision: 0.9914 - recall: 0.9935 - auc: 0.9990 - f1_score: 0.9925
# Test Accuracy for trial 3: 0.9921875
# Model saved as models/diff_seeds/DenseNet3.h5
# Trial 4
# Epoch 1/10
# 73/73 - 74s - loss: 0.5653 - accuracy: 0.9418 - precision: 0.9386 - recall: 0.9443 - auc: 0.9875 - f1_score: 0.9415 - val_loss: 0.3358 - val_accuracy: 0.9804 - val_precision: 0.9793 - val_recall: 0.9820 - val_auc: 0.9984 - val_f1_score: 0.9806 - 74s/epoch - 1s/step
# Epoch 2/10
# 73/73 - 67s - loss: 0.2988 - accuracy: 0.9819 - precision: 0.9807 - recall: 0.9830 - auc: 0.9983 - f1_score: 0.9818 - val_loss: 0.2580 - val_accuracy: 0.9839 - val_precision: 0.9881 - val_recall: 0.9799 - val_auc: 0.9990 - val_f1_score: 0.9840 - 67s/epoch - 914ms/step
# Epoch 3/10
# 73/73 - 67s - loss: 0.2379 - accuracy: 0.9817 - precision: 0.9806 - recall: 0.9826 - auc: 0.9984 - f1_score: 0.9816 - val_loss: 0.2145 - val_accuracy: 0.9822 - val_precision: 0.9922 - val_recall: 0.9723 - val_auc: 0.9991 - val_f1_score: 0.9822 - 67s/epoch - 919ms/step
# Epoch 4/10
# 73/73 - 67s - loss: 0.1967 - accuracy: 0.9826 - precision: 0.9822 - recall: 0.9827 - auc: 0.9985 - f1_score: 0.9825 - val_loss: 0.1747 - val_accuracy: 0.9836 - val_precision: 0.9881 - val_recall: 0.9792 - val_auc: 0.9991 - val_f1_score: 0.9837 - 67s/epoch - 917ms/step
# Epoch 5/10
# 73/73 - 66s - loss: 0.1634 - accuracy: 0.9840 - precision: 0.9840 - recall: 0.9839 - auc: 0.9987 - f1_score: 0.9839 - val_loss: 0.1532 - val_accuracy: 0.9836 - val_precision: 0.9922 - val_recall: 0.9751 - val_auc: 0.9992 - val_f1_score: 0.9836 - 66s/epoch - 898ms/step
# Epoch 6/10
# 73/73 - 67s - loss: 0.1420 - accuracy: 0.9837 - precision: 0.9839 - recall: 0.9832 - auc: 0.9986 - f1_score: 0.9835 - val_loss: 0.1350 - val_accuracy: 0.9801 - val_precision: 0.9929 - val_recall: 0.9675 - val_auc: 0.9992 - val_f1_score: 0.9800 - 67s/epoch - 913ms/step
# Epoch 7/10
# 73/73 - 66s - loss: 0.1244 - accuracy: 0.9839 - precision: 0.9835 - recall: 0.9841 - auc: 0.9986 - f1_score: 0.9838 - val_loss: 0.1264 - val_accuracy: 0.9783 - val_precision: 0.9936 - val_recall: 0.9633 - val_auc: 0.9992 - val_f1_score: 0.9782 - 66s/epoch - 898ms/step
# Epoch 8/10
# 73/73 - 66s - loss: 0.1098 - accuracy: 0.9840 - precision: 0.9832 - recall: 0.9845 - auc: 0.9989 - f1_score: 0.9839 - val_loss: 0.1081 - val_accuracy: 0.9808 - val_precision: 0.9922 - val_recall: 0.9695 - val_auc: 0.9992 - val_f1_score: 0.9807 - 66s/epoch - 907ms/step
# Epoch 9/10
# 73/73 - 66s - loss: 0.0965 - accuracy: 0.9854 - precision: 0.9843 - recall: 0.9864 - auc: 0.9988 - f1_score: 0.9853 - val_loss: 0.1047 - val_accuracy: 0.9790 - val_precision: 0.9936 - val_recall: 0.9647 - val_auc: 0.9992 - val_f1_score: 0.9789 - 66s/epoch - 908ms/step
# Epoch 10/10
# 73/73 - 66s - loss: 0.0900 - accuracy: 0.9854 - precision: 0.9852 - recall: 0.9854 - auc: 0.9986 - f1_score: 0.9853 - val_loss: 0.0944 - val_accuracy: 0.9790 - val_precision: 0.9943 - val_recall: 0.9640 - val_auc: 0.9992 - val_f1_score: 0.9789 - 66s/epoch - 907ms/step
# Validation Accuracy for trial 4: 0.9839161038398743
# 7/7 [==============================] - 6s 799ms/step - loss: 0.0841 - accuracy: 0.9877 - precision: 0.9967 - recall: 0.9795 - auc: 0.9989 - f1_score: 0.9880
# Test Accuracy for trial 4: 0.9877232313156128
# Model saved as models/diff_seeds/DenseNet4.h5
# Trial 5
# Epoch 1/10
# 73/73 - 72s - loss: 0.4468 - accuracy: 0.9675 - precision: 0.9652 - recall: 0.9695 - auc: 0.9951 - f1_score: 0.9673 - val_loss: 0.2563 - val_accuracy: 0.9825 - val_precision: 0.9888 - val_recall: 0.9765 - val_auc: 0.9990 - val_f1_score: 0.9826 - 72s/epoch - 991ms/step
# Epoch 2/10
# 73/73 - 66s - loss: 0.2186 - accuracy: 0.9819 - precision: 0.9810 - recall: 0.9827 - auc: 0.9983 - f1_score: 0.9818 - val_loss: 0.1768 - val_accuracy: 0.9825 - val_precision: 0.9874 - val_recall: 0.9778 - val_auc: 0.9991 - val_f1_score: 0.9826 - 66s/epoch - 903ms/step
# Epoch 3/10
# 73/73 - 66s - loss: 0.1582 - accuracy: 0.9832 - precision: 0.9821 - recall: 0.9842 - auc: 0.9986 - f1_score: 0.9831 - val_loss: 0.1371 - val_accuracy: 0.9829 - val_precision: 0.9902 - val_recall: 0.9758 - val_auc: 0.9992 - val_f1_score: 0.9829 - 66s/epoch - 902ms/step
# Epoch 4/10
# 73/73 - 66s - loss: 0.1263 - accuracy: 0.9824 - precision: 0.9824 - recall: 0.9820 - auc: 0.9985 - f1_score: 0.9822 - val_loss: 0.1106 - val_accuracy: 0.9832 - val_precision: 0.9888 - val_recall: 0.9778 - val_auc: 0.9992 - val_f1_score: 0.9833 - 66s/epoch - 901ms/step
# Epoch 5/10
# 73/73 - 66s - loss: 0.1026 - accuracy: 0.9847 - precision: 0.9847 - recall: 0.9845 - auc: 0.9988 - f1_score: 0.9846 - val_loss: 0.0934 - val_accuracy: 0.9839 - val_precision: 0.9895 - val_recall: 0.9785 - val_auc: 0.9992 - val_f1_score: 0.9840 - 66s/epoch - 907ms/step
# Epoch 6/10
# 73/73 - 67s - loss: 0.0904 - accuracy: 0.9850 - precision: 0.9856 - recall: 0.9842 - auc: 0.9985 - f1_score: 0.9849 - val_loss: 0.0808 - val_accuracy: 0.9839 - val_precision: 0.9847 - val_recall: 0.9834 - val_auc: 0.9992 - val_f1_score: 0.9841 - 67s/epoch - 919ms/step
# Epoch 7/10
# 73/73 - 66s - loss: 0.0796 - accuracy: 0.9847 - precision: 0.9849 - recall: 0.9842 - auc: 0.9988 - f1_score: 0.9846 - val_loss: 0.0738 - val_accuracy: 0.9843 - val_precision: 0.9821 - val_recall: 0.9868 - val_auc: 0.9992 - val_f1_score: 0.9845 - 66s/epoch - 905ms/step
# Epoch 8/10
# 73/73 - 67s - loss: 0.0739 - accuracy: 0.9844 - precision: 0.9845 - recall: 0.9840 - auc: 0.9988 - f1_score: 0.9842 - val_loss: 0.0688 - val_accuracy: 0.9846 - val_precision: 0.9821 - val_recall: 0.9875 - val_auc: 0.9992 - val_f1_score: 0.9848 - 67s/epoch - 918ms/step
# Epoch 9/10
# 73/73 - 66s - loss: 0.0712 - accuracy: 0.9836 - precision: 0.9840 - recall: 0.9830 - auc: 0.9987 - f1_score: 0.9835 - val_loss: 0.0640 - val_accuracy: 0.9857 - val_precision: 0.9861 - val_recall: 0.9855 - val_auc: 0.9992 - val_f1_score: 0.9858 - 66s/epoch - 899ms/step
# Epoch 10/10
# 73/73 - 66s - loss: 0.0665 - accuracy: 0.9841 - precision: 0.9837 - recall: 0.9843 - auc: 0.9988 - f1_score: 0.9840 - val_loss: 0.0628 - val_accuracy: 0.9850 - val_precision: 0.9888 - val_recall: 0.9813 - val_auc: 0.9992 - val_f1_score: 0.9851 - 66s/epoch - 897ms/step
# Validation Accuracy for trial 5: 0.9825174808502197
# 7/7 [==============================] - 6s 801ms/step - loss: 0.0554 - accuracy: 0.9911 - precision: 0.9935 - recall: 0.9892 - auc: 0.9990 - f1_score: 0.9914
# Test Accuracy for trial 5: 0.9910714030265808
# Model saved as models/diff_seeds/DenseNet5.h5
# Trial 6
# Epoch 1/10
# 73/73 - 72s - loss: 0.4939 - accuracy: 0.9573 - precision: 0.9554 - recall: 0.9587 - auc: 0.9936 - f1_score: 0.9571 - val_loss: 0.3016 - val_accuracy: 0.9797 - val_precision: 0.9846 - val_recall: 0.9751 - val_auc: 0.9984 - val_f1_score: 0.9798 - 72s/epoch - 988ms/step
# Epoch 2/10
# 73/73 - 66s - loss: 0.2596 - accuracy: 0.9817 - precision: 0.9813 - recall: 0.9819 - auc: 0.9982 - f1_score: 0.9816 - val_loss: 0.2252 - val_accuracy: 0.9783 - val_precision: 0.9929 - val_recall: 0.9640 - val_auc: 0.9990 - val_f1_score: 0.9782 - 66s/epoch - 901ms/step
# Epoch 3/10
# 73/73 - 66s - loss: 0.1959 - accuracy: 0.9825 - precision: 0.9816 - recall: 0.9831 - auc: 0.9983 - f1_score: 0.9824 - val_loss: 0.1786 - val_accuracy: 0.9787 - val_precision: 0.9929 - val_recall: 0.9647 - val_auc: 0.9991 - val_f1_score: 0.9786 - 66s/epoch - 898ms/step
# Epoch 4/10
# 73/73 - 66s - loss: 0.1544 - accuracy: 0.9836 - precision: 0.9833 - recall: 0.9835 - auc: 0.9984 - f1_score: 0.9834 - val_loss: 0.1379 - val_accuracy: 0.9832 - val_precision: 0.9902 - val_recall: 0.9765 - val_auc: 0.9992 - val_f1_score: 0.9833 - 66s/epoch - 906ms/step
# Epoch 5/10
# 73/73 - 67s - loss: 0.1312 - accuracy: 0.9824 - precision: 0.9815 - recall: 0.9830 - auc: 0.9983 - f1_score: 0.9822 - val_loss: 0.1260 - val_accuracy: 0.9787 - val_precision: 0.9943 - val_recall: 0.9633 - val_auc: 0.9992 - val_f1_score: 0.9785 - 67s/epoch - 920ms/step
# Epoch 6/10
# 73/73 - 67s - loss: 0.1106 - accuracy: 0.9833 - precision: 0.9828 - recall: 0.9835 - auc: 0.9986 - f1_score: 0.9832 - val_loss: 0.1093 - val_accuracy: 0.9801 - val_precision: 0.9943 - val_recall: 0.9661 - val_auc: 0.9992 - val_f1_score: 0.9800 - 67s/epoch - 916ms/step
# Epoch 7/10
# 73/73 - 67s - loss: 0.0965 - accuracy: 0.9830 - precision: 0.9825 - recall: 0.9832 - auc: 0.9987 - f1_score: 0.9828 - val_loss: 0.0932 - val_accuracy: 0.9829 - val_precision: 0.9943 - val_recall: 0.9716 - val_auc: 0.9992 - val_f1_score: 0.9828 - 67s/epoch - 913ms/step
# Epoch 8/10
# 73/73 - 67s - loss: 0.0843 - accuracy: 0.9845 - precision: 0.9842 - recall: 0.9845 - auc: 0.9989 - f1_score: 0.9844 - val_loss: 0.0891 - val_accuracy: 0.9815 - val_precision: 0.9950 - val_recall: 0.9681 - val_auc: 0.9992 - val_f1_score: 0.9814 - 67s/epoch - 921ms/step
# Epoch 9/10
# 73/73 - 67s - loss: 0.0758 - accuracy: 0.9858 - precision: 0.9859 - recall: 0.9854 - auc: 0.9988 - f1_score: 0.9856 - val_loss: 0.0806 - val_accuracy: 0.9811 - val_precision: 0.9922 - val_recall: 0.9702 - val_auc: 0.9992 - val_f1_score: 0.9811 - 67s/epoch - 916ms/step
# Epoch 10/10
# 73/73 - 66s - loss: 0.0725 - accuracy: 0.9847 - precision: 0.9845 - recall: 0.9847 - auc: 0.9988 - f1_score: 0.9846 - val_loss: 0.0716 - val_accuracy: 0.9822 - val_precision: 0.9888 - val_recall: 0.9758 - val_auc: 0.9991 - val_f1_score: 0.9822 - 66s/epoch - 911ms/step
# Validation Accuracy for trial 6: 0.9783216714859009
# 7/7 [==============================] - 6s 791ms/step - loss: 0.0613 - accuracy: 0.9888 - precision: 0.9924 - recall: 0.9860 - auc: 0.9990 - f1_score: 0.9892
# Test Accuracy for trial 6: 0.9888392686843872
# Model saved as models/diff_seeds/DenseNet6.h5
# Trial 7
# Epoch 1/10
# 73/73 - 73s - loss: 0.5338 - accuracy: 0.9506 - precision: 0.9478 - recall: 0.9528 - auc: 0.9910 - f1_score: 0.9503 - val_loss: 0.3269 - val_accuracy: 0.9822 - val_precision: 0.9840 - val_recall: 0.9806 - val_auc: 0.9987 - val_f1_score: 0.9823 - 73s/epoch - 999ms/step
# Epoch 2/10
# 73/73 - 67s - loss: 0.2884 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9813 - auc: 0.9983 - f1_score: 0.9814 - val_loss: 0.2503 - val_accuracy: 0.9818 - val_precision: 0.9895 - val_recall: 0.9744 - val_auc: 0.9991 - val_f1_score: 0.9819 - 67s/epoch - 919ms/step
# Epoch 3/10
# 73/73 - 66s - loss: 0.2259 - accuracy: 0.9825 - precision: 0.9821 - recall: 0.9826 - auc: 0.9985 - f1_score: 0.9823 - val_loss: 0.2067 - val_accuracy: 0.9808 - val_precision: 0.9922 - val_recall: 0.9695 - val_auc: 0.9991 - val_f1_score: 0.9807 - 66s/epoch - 910ms/step
# Epoch 4/10
# 73/73 - 67s - loss: 0.1857 - accuracy: 0.9822 - precision: 0.9817 - recall: 0.9823 - auc: 0.9984 - f1_score: 0.9820 - val_loss: 0.1840 - val_accuracy: 0.9752 - val_precision: 0.9957 - val_recall: 0.9550 - val_auc: 0.9991 - val_f1_score: 0.9749 - 67s/epoch - 914ms/step
# Epoch 5/10
# 73/73 - 66s - loss: 0.1543 - accuracy: 0.9830 - precision: 0.9826 - recall: 0.9831 - auc: 0.9985 - f1_score: 0.9828 - val_loss: 0.1540 - val_accuracy: 0.9780 - val_precision: 0.9950 - val_recall: 0.9612 - val_auc: 0.9992 - val_f1_score: 0.9778 - 66s/epoch - 903ms/step
# Epoch 6/10
# 73/73 - 67s - loss: 0.1292 - accuracy: 0.9846 - precision: 0.9846 - recall: 0.9844 - auc: 0.9988 - f1_score: 0.9845 - val_loss: 0.1289 - val_accuracy: 0.9815 - val_precision: 0.9929 - val_recall: 0.9702 - val_auc: 0.9992 - val_f1_score: 0.9814 - 67s/epoch - 922ms/step
# Epoch 7/10
# 73/73 - 66s - loss: 0.1133 - accuracy: 0.9839 - precision: 0.9838 - recall: 0.9839 - auc: 0.9988 - f1_score: 0.9838 - val_loss: 0.1093 - val_accuracy: 0.9832 - val_precision: 0.9936 - val_recall: 0.9730 - val_auc: 0.9993 - val_f1_score: 0.9832 - 66s/epoch - 903ms/step
# Epoch 8/10
# 73/73 - 66s - loss: 0.0995 - accuracy: 0.9851 - precision: 0.9842 - recall: 0.9857 - auc: 0.9988 - f1_score: 0.9850 - val_loss: 0.1013 - val_accuracy: 0.9818 - val_precision: 0.9929 - val_recall: 0.9709 - val_auc: 0.9992 - val_f1_score: 0.9818 - 66s/epoch - 904ms/step
# Epoch 9/10
# 73/73 - 67s - loss: 0.0866 - accuracy: 0.9874 - precision: 0.9865 - recall: 0.9881 - auc: 0.9989 - f1_score: 0.9873 - val_loss: 0.0845 - val_accuracy: 0.9850 - val_precision: 0.9895 - val_recall: 0.9806 - val_auc: 0.9993 - val_f1_score: 0.9850 - 67s/epoch - 911ms/step
# Epoch 10/10
# 73/73 - 66s - loss: 0.0824 - accuracy: 0.9855 - precision: 0.9855 - recall: 0.9854 - auc: 0.9988 - f1_score: 0.9854 - val_loss: 0.0793 - val_accuracy: 0.9843 - val_precision: 0.9895 - val_recall: 0.9792 - val_auc: 0.9992 - val_f1_score: 0.9843 - 66s/epoch - 901ms/step
# Validation Accuracy for trial 7: 0.9818181991577148
# 7/7 [==============================] - 6s 806ms/step - loss: 0.0720 - accuracy: 0.9894 - precision: 0.9935 - recall: 0.9860 - auc: 0.9990 - f1_score: 0.9897
# Test Accuracy for trial 7: 0.9893973469734192
# Model saved as models/diff_seeds/DenseNet7.h5
# Trial 8
# Epoch 1/10
# 73/73 - 74s - loss: 0.5788 - accuracy: 0.9399 - precision: 0.9369 - recall: 0.9423 - auc: 0.9863 - f1_score: 0.9396 - val_loss: 0.3435 - val_accuracy: 0.9822 - val_precision: 0.9787 - val_recall: 0.9861 - val_auc: 0.9983 - val_f1_score: 0.9824 - 74s/epoch - 1s/step
# Epoch 2/10
# 73/73 - 68s - loss: 0.3085 - accuracy: 0.9812 - precision: 0.9794 - recall: 0.9829 - auc: 0.9981 - f1_score: 0.9811 - val_loss: 0.2682 - val_accuracy: 0.9832 - val_precision: 0.9888 - val_recall: 0.9778 - val_auc: 0.9990 - val_f1_score: 0.9833 - 68s/epoch - 925ms/step
# Epoch 3/10
# 73/73 - 67s - loss: 0.2479 - accuracy: 0.9817 - precision: 0.9819 - recall: 0.9812 - auc: 0.9984 - f1_score: 0.9815 - val_loss: 0.2195 - val_accuracy: 0.9825 - val_precision: 0.9888 - val_recall: 0.9765 - val_auc: 0.9991 - val_f1_score: 0.9826 - 67s/epoch - 914ms/step
# Epoch 4/10
# 73/73 - 66s - loss: 0.2028 - accuracy: 0.9838 - precision: 0.9835 - recall: 0.9838 - auc: 0.9986 - f1_score: 0.9836 - val_loss: 0.1896 - val_accuracy: 0.9822 - val_precision: 0.9915 - val_recall: 0.9730 - val_auc: 0.9992 - val_f1_score: 0.9822 - 66s/epoch - 909ms/step
# Epoch 5/10
# 73/73 - 67s - loss: 0.1733 - accuracy: 0.9833 - precision: 0.9825 - recall: 0.9840 - auc: 0.9986 - f1_score: 0.9832 - val_loss: 0.1619 - val_accuracy: 0.9822 - val_precision: 0.9929 - val_recall: 0.9716 - val_auc: 0.9992 - val_f1_score: 0.9821 - 67s/epoch - 918ms/step
# Epoch 6/10
# 73/73 - 66s - loss: 0.1442 - accuracy: 0.9850 - precision: 0.9843 - recall: 0.9854 - auc: 0.9988 - f1_score: 0.9848 - val_loss: 0.1384 - val_accuracy: 0.9818 - val_precision: 0.9901 - val_recall: 0.9737 - val_auc: 0.9992 - val_f1_score: 0.9818 - 66s/epoch - 906ms/step
# Epoch 7/10
# 73/73 - 66s - loss: 0.1289 - accuracy: 0.9841 - precision: 0.9834 - recall: 0.9846 - auc: 0.9986 - f1_score: 0.9840 - val_loss: 0.1269 - val_accuracy: 0.9808 - val_precision: 0.9929 - val_recall: 0.9688 - val_auc: 0.9992 - val_f1_score: 0.9807 - 66s/epoch - 908ms/step
# Epoch 8/10
# 73/73 - 66s - loss: 0.1151 - accuracy: 0.9837 - precision: 0.9831 - recall: 0.9841 - auc: 0.9987 - f1_score: 0.9836 - val_loss: 0.1144 - val_accuracy: 0.9818 - val_precision: 0.9957 - val_recall: 0.9681 - val_auc: 0.9993 - val_f1_score: 0.9817 - 66s/epoch - 909ms/step
# Epoch 9/10
# 73/73 - 66s - loss: 0.1005 - accuracy: 0.9846 - precision: 0.9839 - recall: 0.9851 - auc: 0.9987 - f1_score: 0.9845 - val_loss: 0.0999 - val_accuracy: 0.9815 - val_precision: 0.9908 - val_recall: 0.9723 - val_auc: 0.9992 - val_f1_score: 0.9815 - 66s/epoch - 902ms/step
# Epoch 10/10
# 73/73 - 66s - loss: 0.0929 - accuracy: 0.9851 - precision: 0.9852 - recall: 0.9847 - auc: 0.9987 - f1_score: 0.9849 - val_loss: 0.0909 - val_accuracy: 0.9818 - val_precision: 0.9901 - val_recall: 0.9737 - val_auc: 0.9993 - val_f1_score: 0.9818 - 66s/epoch - 907ms/step
# Validation Accuracy for trial 8: 0.9832167625427246
# 7/7 [==============================] - 6s 800ms/step - loss: 0.0814 - accuracy: 0.9883 - precision: 0.9945 - recall: 0.9828 - auc: 0.9990 - f1_score: 0.9886
# Test Accuracy for trial 8: 0.98828125
# Model saved as models/diff_seeds/DenseNet8.h5
# Trial 9
# Epoch 1/10
# 73/73 - 74s - loss: 0.5104 - accuracy: 0.9558 - precision: 0.9545 - recall: 0.9566 - auc: 0.9925 - f1_score: 0.9555 - val_loss: 0.3104 - val_accuracy: 0.9822 - val_precision: 0.9860 - val_recall: 0.9785 - val_auc: 0.9988 - val_f1_score: 0.9823 - 74s/epoch - 1s/step
# Epoch 2/10
# 73/73 - 67s - loss: 0.2735 - accuracy: 0.9815 - precision: 0.9810 - recall: 0.9817 - auc: 0.9981 - f1_score: 0.9813 - val_loss: 0.2414 - val_accuracy: 0.9794 - val_precision: 0.9943 - val_recall: 0.9647 - val_auc: 0.9991 - val_f1_score: 0.9793 - 67s/epoch - 916ms/step
# Epoch 3/10
# 73/73 - 67s - loss: 0.2115 - accuracy: 0.9836 - precision: 0.9828 - recall: 0.9842 - auc: 0.9984 - f1_score: 0.9835 - val_loss: 0.1969 - val_accuracy: 0.9808 - val_precision: 0.9957 - val_recall: 0.9661 - val_auc: 0.9992 - val_f1_score: 0.9807 - 67s/epoch - 918ms/step
# Epoch 4/10
# 73/73 - 67s - loss: 0.1701 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9841 - auc: 0.9986 - f1_score: 0.9842 - val_loss: 0.1550 - val_accuracy: 0.9822 - val_precision: 0.9915 - val_recall: 0.9730 - val_auc: 0.9992 - val_f1_score: 0.9822 - 67s/epoch - 920ms/step
# Epoch 5/10
# 73/73 - 67s - loss: 0.1415 - accuracy: 0.9848 - precision: 0.9845 - recall: 0.9849 - auc: 0.9986 - f1_score: 0.9847 - val_loss: 0.1296 - val_accuracy: 0.9832 - val_precision: 0.9909 - val_recall: 0.9758 - val_auc: 0.9992 - val_f1_score: 0.9833 - 67s/epoch - 922ms/step
# Epoch 6/10
# 73/73 - 68s - loss: 0.1235 - accuracy: 0.9831 - precision: 0.9827 - recall: 0.9832 - auc: 0.9984 - f1_score: 0.9829 - val_loss: 0.1110 - val_accuracy: 0.9853 - val_precision: 0.9909 - val_recall: 0.9799 - val_auc: 0.9992 - val_f1_score: 0.9854 - 68s/epoch - 930ms/step
# Epoch 7/10
# 73/73 - 68s - loss: 0.1081 - accuracy: 0.9828 - precision: 0.9829 - recall: 0.9825 - auc: 0.9987 - f1_score: 0.9827 - val_loss: 0.1093 - val_accuracy: 0.9794 - val_precision: 0.9943 - val_recall: 0.9647 - val_auc: 0.9992 - val_f1_score: 0.9793 - 68s/epoch - 930ms/step
# Epoch 8/10
# 73/73 - 68s - loss: 0.0958 - accuracy: 0.9845 - precision: 0.9834 - recall: 0.9854 - auc: 0.9987 - f1_score: 0.9844 - val_loss: 0.0956 - val_accuracy: 0.9811 - val_precision: 0.9936 - val_recall: 0.9688 - val_auc: 0.9992 - val_f1_score: 0.9811 - 68s/epoch - 934ms/step
# Epoch 9/10
# 73/73 - 68s - loss: 0.0852 - accuracy: 0.9853 - precision: 0.9844 - recall: 0.9859 - auc: 0.9988 - f1_score: 0.9852 - val_loss: 0.0867 - val_accuracy: 0.9811 - val_precision: 0.9929 - val_recall: 0.9695 - val_auc: 0.9992 - val_f1_score: 0.9811 - 68s/epoch - 928ms/step
# Epoch 10/10
# 73/73 - 68s - loss: 0.0786 - accuracy: 0.9847 - precision: 0.9839 - recall: 0.9854 - auc: 0.9987 - f1_score: 0.9846 - val_loss: 0.0841 - val_accuracy: 0.9804 - val_precision: 0.9936 - val_recall: 0.9675 - val_auc: 0.9992 - val_f1_score: 0.9804 - 68s/epoch - 925ms/step
# Validation Accuracy for trial 9: 0.979370653629303
# 7/7 [==============================] - 6s 799ms/step - loss: 0.0759 - accuracy: 0.9849 - precision: 0.9956 - recall: 0.9752 - auc: 0.9984 - f1_score: 0.9853
# Test Accuracy for trial 9: 0.9849330186843872
# Model saved as models/diff_seeds/DenseNet9.h5
# Trial 10
# Epoch 1/10
# 73/73 - 75s - loss: 0.4879 - accuracy: 0.9591 - precision: 0.9567 - recall: 0.9611 - auc: 0.9941 - f1_score: 0.9589 - val_loss: 0.3047 - val_accuracy: 0.9790 - val_precision: 0.9922 - val_recall: 0.9661 - val_auc: 0.9988 - val_f1_score: 0.9789 - 75s/epoch - 1s/step
# Epoch 2/10
# 73/73 - 67s - loss: 0.2596 - accuracy: 0.9816 - precision: 0.9809 - recall: 0.9820 - auc: 0.9982 - f1_score: 0.9814 - val_loss: 0.2309 - val_accuracy: 0.9759 - val_precision: 0.9935 - val_recall: 0.9584 - val_auc: 0.9991 - val_f1_score: 0.9757 - 67s/epoch - 924ms/step
# Epoch 3/10
# 73/73 - 67s - loss: 0.1952 - accuracy: 0.9823 - precision: 0.9821 - recall: 0.9821 - auc: 0.9985 - f1_score: 0.9821 - val_loss: 0.1697 - val_accuracy: 0.9832 - val_precision: 0.9902 - val_recall: 0.9765 - val_auc: 0.9991 - val_f1_score: 0.9833 - 67s/epoch - 924ms/step
# Epoch 4/10
# 73/73 - 66s - loss: 0.1592 - accuracy: 0.9809 - precision: 0.9808 - recall: 0.9807 - auc: 0.9983 - f1_score: 0.9808 - val_loss: 0.1438 - val_accuracy: 0.9815 - val_precision: 0.9915 - val_recall: 0.9716 - val_auc: 0.9991 - val_f1_score: 0.9815 - 66s/epoch - 910ms/step
# Epoch 5/10
# 73/73 - 67s - loss: 0.1297 - accuracy: 0.9834 - precision: 0.9830 - recall: 0.9836 - auc: 0.9987 - f1_score: 0.9833 - val_loss: 0.1242 - val_accuracy: 0.9801 - val_precision: 0.9929 - val_recall: 0.9675 - val_auc: 0.9992 - val_f1_score: 0.9800 - 67s/epoch - 922ms/step
# Epoch 6/10
# 73/73 - 67s - loss: 0.1109 - accuracy: 0.9830 - precision: 0.9832 - recall: 0.9826 - auc: 0.9987 - f1_score: 0.9829 - val_loss: 0.1199 - val_accuracy: 0.9755 - val_precision: 0.9957 - val_recall: 0.9557 - val_auc: 0.9992 - val_f1_score: 0.9753 - 67s/epoch - 922ms/step
# Epoch 7/10
# 73/73 - 67s - loss: 0.0943 - accuracy: 0.9854 - precision: 0.9847 - recall: 0.9859 - auc: 0.9989 - f1_score: 0.9853 - val_loss: 0.0935 - val_accuracy: 0.9811 - val_precision: 0.9915 - val_recall: 0.9709 - val_auc: 0.9992 - val_f1_score: 0.9811 - 67s/epoch - 924ms/step
# Epoch 8/10
# 73/73 - 67s - loss: 0.0858 - accuracy: 0.9841 - precision: 0.9834 - recall: 0.9846 - auc: 0.9988 - f1_score: 0.9840 - val_loss: 0.0874 - val_accuracy: 0.9818 - val_precision: 0.9929 - val_recall: 0.9709 - val_auc: 0.9992 - val_f1_score: 0.9818 - 67s/epoch - 922ms/step
# Epoch 9/10
# 73/73 - 68s - loss: 0.0796 - accuracy: 0.9837 - precision: 0.9833 - recall: 0.9838 - auc: 0.9987 - f1_score: 0.9835 - val_loss: 0.0801 - val_accuracy: 0.9832 - val_precision: 0.9929 - val_recall: 0.9737 - val_auc: 0.9992 - val_f1_score: 0.9832 - 68s/epoch - 934ms/step
# Epoch 10/10
# 73/73 - 67s - loss: 0.0716 - accuracy: 0.9853 - precision: 0.9847 - recall: 0.9857 - auc: 0.9990 - f1_score: 0.9852 - val_loss: 0.0779 - val_accuracy: 0.9797 - val_precision: 0.9943 - val_recall: 0.9654 - val_auc: 0.9993 - val_f1_score: 0.9796 - 67s/epoch - 915ms/step
# Validation Accuracy for trial 10: 0.975874125957489
# 7/7 [==============================] - 6s 794ms/step - loss: 0.0694 - accuracy: 0.9860 - precision: 0.9967 - recall: 0.9763 - auc: 0.9990 - f1_score: 0.9864
# Test Accuracy for trial 10: 0.9860491156578064
# Model saved as models/diff_seeds/DenseNet10.h5
