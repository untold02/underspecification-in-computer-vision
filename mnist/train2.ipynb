# %%
import os
import pickle
import contextlib
import gc
import tensorflow                   as tf
import numpy                        as np
import matplotlib.pyplot            as plt
from tensorflow                     import keras
from tensorflow.keras               import layers, models
from tensorflow.keras.regularizers  import l2

# %%
(train_images, train_labels), (val_images, val_labels) = tf.keras.datasets.mnist.load_data()

train_images  = np.expand_dims(train_images, axis=-1)
val_images    = np.expand_dims(val_images, axis=-1)

train_images  = train_images.astype('float32')/255.0
val_images    = val_images.astype('float32')/255.0

train_images  = tf.image.grayscale_to_rgb(tf.image.resize(train_images, (32,32)))
val_images    = tf.image.grayscale_to_rgb(tf.image.resize(val_images, (32,32)))

# take 2000 data points as reserve
test_images   = val_images[8000:]
val_images    = val_images[:8000]

test_labels   = val_labels[8000:]
val_labels    = val_labels[:8000]

train_labels  = tf.keras.utils.to_categorical(train_labels, 10)
val_labels    = tf.keras.utils.to_categorical(val_labels, 10)
test_labels   = tf.keras.utils.to_categorical(test_labels, 10)

batch_size    = 64

def data_generator(images, labels, batch_size = batch_size):
    dataset   = tf.data.Dataset.from_tensor_slices((images, labels))
    dataset   = dataset.cache()
    dataset   = dataset.shuffle(20000)
    dataset   = dataset.batch(batch_size)
    dataset   = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_dataset = data_generator(train_images, train_labels)
val_dataset   = data_generator(val_images, val_labels)
test_dataset  = data_generator(test_images, test_labels)
# Out:
# 2024-10-17 14:32:57.675674: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.backend import epsilon

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall    = Recall()

    def update_state(self, y_true, y_pred, sample_weight = None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        f = 2 * ((p * r) / (p + r + epsilon()))
        return f

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
import random

def set_random_seeds(seed_value):
    np.random.seed(seed_value)
    random.seed(seed_value)
    tf.random.set_seed(seed_value)

# %%
def create_model():
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape            = (32, 32, 3)),
            layers.Conv2D(32, kernel_size   = (3, 3), activation = "relu"),
            layers.BatchNormalization(),
            layers.MaxPooling2D(pool_size   = (2, 2)),
            
            layers.Conv2D(64, kernel_size   = (3, 3), activation="relu"),
            layers.BatchNormalization(),
            layers.MaxPooling2D(pool_size   = (2, 2)),

            layers.Conv2D(128, kernel_size  = (3, 3), activation="relu"),
            layers.BatchNormalization(),
            layers.MaxPooling2D(pool_size   = (2, 2)),

            layers.GlobalAveragePooling2D(),
            layers.Dropout(0.3),
            layers.Dense(128,
                         activation         = "relu",
                         kernel_regularizer = l2(0.001)
                        ),
            layers.Dropout(0.3),
            layers.Dense(10, 
                         activation         = "softmax",
                         kernel_regularizer = l2(0.001)
                        )
        ]
    )
    
    model.compile(optimizer = 'adam',
                  loss      = 'categorical_crossentropy',
                  metrics   = ['accuracy',
                              Precision(name = 'precision'),
                              Recall(name    = 'recall'),
                              AUC(name       = 'auc'),
                              F1Score(name   = 'f1_score')
                              ]
                 )
    return model

# %%
num_trials = 10
results = []

save_dir = "models/diff_seeds"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for i in range(num_trials):
    print(f"Trial {i+1}")
    
    seed     = i  # Different seed for each trial
    set_random_seeds(seed)

    # create a new model for each trial with a fresh initialization
    model    = create_model()
    
    history  = model.fit(train_dataset,
                         validation_data = val_dataset,
                         epochs          = 15,
                         verbose         = 2)

    train_loss = history.history["loss"][-1]
    train_acc  = history.history["accuracy"][-1]
    val_loss   = history.history["val_loss"][-1]
    val_acc    = history.history["val_accuracy"][-1]
    print(f"Validation Accuracy for trial {i+1}: {val_acc}")

    test_loss, test_acc, _, _, _, _ = model.evaluate(test_dataset)
    print(f"Test Accuracy for trial {i+1}: {test_acc}")
    
    results.append({
        'trial'      : i+1,
        'seed'       : seed,
        'train_loss' : train_loss,
        'train_acc'  : train_acc,
        'val_loss'   : val_loss,
        'val_acc'    : val_acc,
        'test_loss'  : test_loss,
        'test_acc'   : test_acc,
        'history'    : history.history
    })
    
    model_name = f'CNN{i+1}.h5'
    model_path = os.path.join(save_dir, model_name)

    # Save the model if train, validation and test accuracy are greater than the threshold "t"
    if train_acc > 0.98 and val_acc > 0.98 and test_acc > 0.98:
        model.save(model_path)
        print(f"Model saved as {model_path}")
# Out:
# Trial 1
# Epoch 1/15
# 938/938 - 9s - loss: 0.3282 - accuracy: 0.9355 - precision: 0.9646 - recall: 0.9138 - auc: 0.9965 - f1_score: 0.9385 - val_loss: 0.1492 - val_accuracy: 0.9824 - val_precision: 0.9860 - val_recall: 0.9789 - val_auc: 0.9994 - val_f1_score: 0.9824 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.1356 - accuracy: 0.9812 - precision: 0.9845 - recall: 0.9775 - auc: 0.9992 - f1_score: 0.9810 - val_loss: 0.0927 - val_accuracy: 0.9893 - val_precision: 0.9908 - val_recall: 0.9869 - val_auc: 0.9997 - val_f1_score: 0.9889 - 7s/epoch - 8ms/step
# Epoch 3/15
# 938/938 - 7s - loss: 0.0976 - accuracy: 0.9855 - precision: 0.9885 - recall: 0.9829 - auc: 0.9994 - f1_score: 0.9857 - val_loss: 0.0693 - val_accuracy: 0.9905 - val_precision: 0.9933 - val_recall: 0.9886 - val_auc: 0.9999 - val_f1_score: 0.9910 - 7s/epoch - 8ms/step
# Epoch 4/15
# 938/938 - 7s - loss: 0.0786 - accuracy: 0.9882 - precision: 0.9906 - recall: 0.9857 - auc: 0.9996 - f1_score: 0.9882 - val_loss: 0.0843 - val_accuracy: 0.9849 - val_precision: 0.9861 - val_recall: 0.9837 - val_auc: 0.9995 - val_f1_score: 0.9849 - 7s/epoch - 8ms/step
# Epoch 5/15
# 938/938 - 7s - loss: 0.0687 - accuracy: 0.9898 - precision: 0.9920 - recall: 0.9880 - auc: 0.9997 - f1_score: 0.9900 - val_loss: 0.0809 - val_accuracy: 0.9852 - val_precision: 0.9879 - val_recall: 0.9825 - val_auc: 0.9995 - val_f1_score: 0.9852 - 7s/epoch - 8ms/step
# Epoch 6/15
# 938/938 - 7s - loss: 0.0637 - accuracy: 0.9904 - precision: 0.9923 - recall: 0.9886 - auc: 0.9998 - f1_score: 0.9905 - val_loss: 0.0610 - val_accuracy: 0.9908 - val_precision: 0.9921 - val_recall: 0.9894 - val_auc: 0.9997 - val_f1_score: 0.9907 - 7s/epoch - 8ms/step
# Epoch 7/15
# 938/938 - 7s - loss: 0.0588 - accuracy: 0.9917 - precision: 0.9931 - recall: 0.9903 - auc: 0.9998 - f1_score: 0.9917 - val_loss: 0.0651 - val_accuracy: 0.9895 - val_precision: 0.9905 - val_recall: 0.9877 - val_auc: 0.9997 - val_f1_score: 0.9891 - 7s/epoch - 8ms/step
# Epoch 8/15
# 938/938 - 7s - loss: 0.0554 - accuracy: 0.9923 - precision: 0.9936 - recall: 0.9909 - auc: 0.9998 - f1_score: 0.9922 - val_loss: 0.0617 - val_accuracy: 0.9906 - val_precision: 0.9914 - val_recall: 0.9893 - val_auc: 0.9998 - val_f1_score: 0.9903 - 7s/epoch - 8ms/step
# Epoch 9/15
# 938/938 - 7s - loss: 0.0515 - accuracy: 0.9931 - precision: 0.9943 - recall: 0.9919 - auc: 0.9998 - f1_score: 0.9931 - val_loss: 0.0558 - val_accuracy: 0.9904 - val_precision: 0.9916 - val_recall: 0.9894 - val_auc: 0.9997 - val_f1_score: 0.9905 - 7s/epoch - 8ms/step
# Epoch 10/15
# 938/938 - 7s - loss: 0.0492 - accuracy: 0.9935 - precision: 0.9944 - recall: 0.9923 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0583 - val_accuracy: 0.9899 - val_precision: 0.9922 - val_recall: 0.9886 - val_auc: 0.9999 - val_f1_score: 0.9904 - 7s/epoch - 8ms/step
# Epoch 11/15
# 938/938 - 7s - loss: 0.0453 - accuracy: 0.9949 - precision: 0.9957 - recall: 0.9939 - auc: 0.9999 - f1_score: 0.9948 - val_loss: 0.0573 - val_accuracy: 0.9895 - val_precision: 0.9910 - val_recall: 0.9893 - val_auc: 0.9997 - val_f1_score: 0.9901 - 7s/epoch - 8ms/step
# Epoch 12/15
# 938/938 - 7s - loss: 0.0431 - accuracy: 0.9951 - precision: 0.9958 - recall: 0.9943 - auc: 0.9999 - f1_score: 0.9951 - val_loss: 0.0599 - val_accuracy: 0.9887 - val_precision: 0.9897 - val_recall: 0.9880 - val_auc: 0.9995 - val_f1_score: 0.9889 - 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0450 - accuracy: 0.9942 - precision: 0.9951 - recall: 0.9932 - auc: 0.9999 - f1_score: 0.9942 - val_loss: 0.0573 - val_accuracy: 0.9899 - val_precision: 0.9906 - val_recall: 0.9889 - val_auc: 0.9995 - val_f1_score: 0.9897 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0402 - accuracy: 0.9953 - precision: 0.9960 - recall: 0.9945 - auc: 0.9999 - f1_score: 0.9953 - val_loss: 0.0559 - val_accuracy: 0.9908 - val_precision: 0.9925 - val_recall: 0.9893 - val_auc: 0.9996 - val_f1_score: 0.9909 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0380 - accuracy: 0.9962 - precision: 0.9969 - recall: 0.9953 - auc: 0.9999 - f1_score: 0.9961 - val_loss: 0.0550 - val_accuracy: 0.9894 - val_precision: 0.9909 - val_recall: 0.9886 - val_auc: 0.9995 - val_f1_score: 0.9897 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 1: 0.9893749952316284
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9994 - f1_score: 0.9920
# Test Accuracy for trial 1: 0.9919999837875366
# Model saved as models/diff_seeds/CNN1.h5
# Trial 2
# Epoch 1/15
# /opt/conda/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 938/938 - 9s - loss: 0.3249 - accuracy: 0.9376 - precision: 0.9646 - recall: 0.9182 - auc: 0.9965 - f1_score: 0.9409 - val_loss: 0.1365 - val_accuracy: 0.9874 - val_precision: 0.9903 - val_recall: 0.9850 - val_auc: 0.9996 - val_f1_score: 0.9877 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.1400 - accuracy: 0.9804 - precision: 0.9838 - recall: 0.9772 - auc: 0.9992 - f1_score: 0.9805 - val_loss: 0.0951 - val_accuracy: 0.9898 - val_precision: 0.9915 - val_recall: 0.9875 - val_auc: 0.9996 - val_f1_score: 0.9895 - 7s/epoch - 8ms/step
# Epoch 3/15
# 938/938 - 7s - loss: 0.0964 - accuracy: 0.9858 - precision: 0.9886 - recall: 0.9833 - auc: 0.9995 - f1_score: 0.9859 - val_loss: 0.0757 - val_accuracy: 0.9891 - val_precision: 0.9907 - val_recall: 0.9876 - val_auc: 0.9997 - val_f1_score: 0.9892 - 7s/epoch - 8ms/step
# Epoch 4/15
# 938/938 - 7s - loss: 0.
- 7s/epoch - 8ms/step
# Epoch 6/15
# 938/938 - 7s - loss: 0.0628 - accuracy: 0.9910 - precision: 0.9925 - recall: 0.9897 - auc: 0.9998 - f1_score: 0.9911 - val_loss: 0.0673 - val_accuracy: 0.9895 - val_precision: 0.9911 - val_recall: 0.9877 - val_auc: 0.9996 - val_f1_score: 0.9894 - 7s/epoch - 8ms/step
# Epoch 7/15
# 938/938 - 7s - loss: 0.0594 - accuracy: 0.9916 - precision: 0.9931 - recall: 0.9902 - auc: 0.9998 - f1_score: 0.9917 - val_loss: 0.0571 - val_accuracy: 0.9906 - val_precision: 0.9915 - val_recall: 0.9894 - val_auc: 0.9998 - val_f1_score: 0.9904 - 7s/epoch - 8ms/step
# Epoch 8/15
# 938/938 - 7s - loss: 0.0560 - accuracy: 0.9920 - precision: 0.9935 - recall: 0.9905 - auc: 0.9998 - f1_score: 0.9920 - val_loss: 0.0622 - val_accuracy: 0.9896 - val_precision: 0.9906 - val_recall: 0.9886 - val_auc: 0.9997 - val_f1_score: 0.9896 - 7s/epoch - 8ms/step
# Epoch 9/15
# 938/938 - 7s - loss: 0.0514 - accuracy: 0.9931 - precision: 0.9944 - recall: 0.9919 - auc: 0.9999 - f1_score: 0.9931 - val_loss: 0.0534 - val_accuracy: 0.9912 - val_precision: 0.9919 - val_recall: 0.9904 - val_auc: 0.9998 - val_f1_score: 0.9911 - 7s/epoch - 8ms/step
# Epoch 10/15
# 938/938 - 7s - loss: 0.0481 - accuracy: 0.9936 - precision: 0.9947 - recall: 0.9926 - auc: 0.9999 - f1_score: 0.9936 - val_loss: 0.0584 - val_accuracy: 0.9909 - val_precision: 0.9916 - val_recall: 0.9896 - val_auc: 0.9995 - val_f1_score: 0.9906 - 7s/epoch - 8ms/step
# Epoch 11/15
# 938/938 - 7s - loss: 0.0467 - accuracy: 0.9941 - precision: 0.9950 - recall: 0.9931 - auc: 0.9999 - f1_score: 0.9940 - val_loss: 0.0553 - val_accuracy: 0.9906 - val_precision: 0.9921 - val_recall: 0.9901 - val_auc: 0.9996 - val_f1_score: 0.9911 - 7s/epoch - 8ms/step
# Epoch 12/15
# 938/938 - 7s - loss: 0.0435 - accuracy: 0.9949 - precision: 0.9956 - recall: 0.9938 - auc: 0.9999 - f1_score: 0.9947 - val_loss: 0.0585 - val_accuracy: 0.9898 - val_precision: 0.9906 - val_recall: 0.9886 - val_auc: 0.9994 - val_f1_score: 0.9896 - 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0430 - accuracy: 0.9948 - precision: 0.9956 - recall: 0.9940 - auc: 0.9999 - f1_score: 0.9948 - val_loss: 0.0569 - val_accuracy: 0.9890 - val_precision: 0.9905 - val_recall: 0.9881 - val_auc: 0.9997 - val_f1_score: 0.9893 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0395 - accuracy: 0.9958 - precision: 0.9964 - recall: 0.9950 - auc: 1.0000 - f1_score: 0.9957 - val_loss: 0.0497 - val_accuracy: 0.9919 - val_precision: 0.9930 - val_recall: 0.9910 - val_auc: 0.9995 - val_f1_score: 0.9920 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0369 - accuracy: 0.9962 - precision: 0.9967 - recall: 0.9956 - auc: 0.9999 - f1_score: 0.9962 - val_loss: 0.0671 - val_accuracy: 0.9864 - val_precision: 0.9870 - val_recall: 0.9852 - val_auc: 0.9994 - val_f1_score: 0.9861 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 4: 0.9863749742507935
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0543 - accuracy: 0.9885 - precision: 0.9895 - recall: 0.9880 - auc: 0.9999 - f1_score: 0.9887
# Test Accuracy for trial 4: 0.9884999990463257
# Model saved as models/diff_seeds/CNN4.h5
# Trial 5
# Epoch 1/15
# 938/938 - 9s - loss: 0.3300 - accuracy: 0.9368 - precision: 0.9644 - recall: 0.9168 - auc: 0.9965 - f1_score: 0.9400 - val_loss: 0.1599 - val_accuracy: 0.9806 - val_precision: 0.9834 - val_recall: 0.9766 - val_auc: 0.9992 - val_f1_score: 0.9800 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.
- 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0411 - accuracy: 0.9956 - precision: 0.9963 - recall: 0.9948 - auc: 0.9999 - f1_score: 0.9955 - val_loss: 0.0513 - val_accuracy: 0.9908 - val_precision: 0.9912 - val_recall: 0.9900 - val_auc: 0.9998 - val_f1_score: 0.9906 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0397 - accuracy: 0.9956 - precision: 0.9962 - recall: 0.9948 - auc: 0.9999 - f1_score: 0.9955 - val_loss: 0.0529 - val_accuracy: 0.9910 - val_precision: 0.9919 - val_recall: 0.9896 - val_auc: 0.9997 - val_f1_score: 0.9907 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0393 - accuracy: 0.9956 - precision: 0.9963 - recall: 0.9949 - auc: 0.9999 - f1_score: 0.9956 - val_loss: 0.0573 - val_accuracy: 0.9894 - val_precision: 0.9906 - val_recall: 0.9883 - val_auc: 0.9995 - val_f1_score: 0.9894 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 5: 0.9893749952316284
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0476 - accuracy: 0.9935 - precision: 0.9950 - recall: 0.9930 - auc: 0.9997 - f1_score: 0.9940
# Test Accuracy for trial 5: 0.9934999942779541
# Model saved as models/diff_seeds/CNN5.h5
# Trial 6
# Epoch 1/15
# 938/938 - 9s - loss: 0.3378 - accuracy: 0.9352 - precision: 0.9631 - recall: 0.9135 - auc: 0.9963 - f1_score: 0.9377 - val_loss: 0.1568 - val_accuracy: 0.9804 - val_precision: 0.9848 - val_recall: 0.9780 - val_auc: 0.9990 - val_f1_score: 0.9814 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.1418 - accuracy: 0.9804 - precision: 0.9838 - recall: 0.9769 - auc: 0.9991 - f1_score: 0.9803 - val_loss: 0.1049 - val_accuracy: 0.9840 - val_precision: 0.9884 - val_recall: 0.9809 - val_auc: 0.9995 - val_f1_score: 0.9846 - 7s/epoch - 8ms/step
# Epoch 3/15
# 938/938 - 7s - loss: 0.0964 - accuracy: 0.9855 - precision: 0.9884 - recall: 0.9833 - auc: 0.9996 - f1_score: 0.9859 - val_loss: 0.0836 - val_accuracy: 0.9868 - val_precision: 0.9899 - val_recall: 0.9845 - val_auc: 0.9997 - val_f1_score: 0.9872 - 7s/epoch - 8ms/step
# Epoch 4/15
# 938/938 - 7s - loss: 0.0804 - accuracy: 0.9880 - precision: 0.9905 - recall: 0.9858 - auc: 0.9996 - f1_score: 0.9881 - val_loss: 0.0670 - val_accuracy: 0.9896 - val_precision: 0.9912 - val_recall: 0.9879 - val_auc: 0.9997 - val_f1_score: 0.9895 - 7s/epoch - 8ms/step
# Epoch 5/15
# 938/938 - 7s - loss: 0.0711 - accuracy: 0.9894 - precision: 0.9913 - recall: 0.9873 - auc: 0.9997 - f1_score: 0.9893 - val_loss: 0.0604 - val_accuracy: 0.9911 - val_precision: 0.9931 - val_recall: 0.9902 - val_auc: 0.9998 - val_f1_score: 0.9917 - 7s/epoch - 8ms/step
# Epoch 6/15
# 938/938 - 7s - loss: 0.0647 - accuracy: 0.9905 - precision: 0.9923 - recall: 0.9890 - auc: 0.9997 - f1_score: 0.9906 - val_loss: 0.0643 - val_accuracy: 0.9904 - val_precision: 0.9917 - val_recall: 0.9885 - val_auc: 0.9998 - val_f1_score: 0.9901 - 7s/epoch - 8ms/step
# Epoch 7/15
# 938/938 - 7s - loss: 0.0592 - accuracy: 0.9918 - precision: 0.9932 - recall: 0.9899 - auc: 0.9998 - f1_score: 0.9916 - val_loss: 0.0584 - val_accuracy: 0.9910 - val_precision: 0.9920 - val_recall: 0.9887 - val_auc: 0.9997 - val_f1_score: 0.9904 - 7s/epoch - 8ms/step
# Epoch 8/15
# 938/938 - 7s - loss: 0.0553 - accuracy: 0.9925 - precision: 0.9938 - recall: 0.9912 - auc: 0.9998 - f1_score: 0.9925 - val_loss: 0.0597 - val_accuracy: 0.9904 - val_precision: 0.9921 - val_recall: 0.9890 - val_auc: 0.9998 - val_f1_score: 0.9905 - 7s/epoch - 8ms/step
# Epoch 9/15
# 938/938 - 7s - loss: 0.0523 - accuracy: 0.9928 - precision: 0.9943 - recall: 0.9918 - auc: 0.9999 - f1_score: 0.9930 - val_loss: 0.0630 - val_accuracy: 0.9890 - val_precision: 0.9911 - val_recall: 0.9876 - val_auc: 0.9998 - val_f1_score: 0.9894 - 7s/epoch - 8ms/step
# Epoch 10/15
# 938/938 - 7s - loss: 0.0497 - accuracy: 0.9936 - precision: 0.9947 - recall: 0.9924 - auc: 0.9999 - f1_score: 0.9935 - val_loss: 0.0565 - val_accuracy: 0.9908 - val_precision: 0.9922 - val_recall: 0.9899 - val_auc: 0.9995 - val_f1_score: 0.9911 - 7s/epoch - 8ms/step
# Epoch 11/15
# 938/938 - 7s - loss: 0.0467 - accuracy: 0.9945 - precision: 0.9955 - recall: 0.9932 - auc: 0.9999 - f1_score: 0.9943 - val_loss: 0.0552 - val_accuracy: 0.9906 - val_precision: 0.9919 - val_recall: 0.9895 - val_auc: 0.9997 - val_f1_score: 0.9907 - 7s/epoch - 8ms/step
# Epoch 12/15
# 938/938 - 7s - loss: 0.0445 - accuracy: 0.9949 - precision: 0.9957 - recall: 0.9939 - auc: 0.9999 - f1_score: 0.9948 - val_loss: 0.0515 - val_accuracy: 0.9914 - val_precision: 0.9926 - val_recall: 0.9900 - val_auc: 0.9997 - val_f1_score: 0.9913 - 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0418 - accuracy: 0.9953 - precision: 0.9961 - recall: 0.9945 - auc: 0.9999 - f1_score: 0.9953 - val_loss: 0.0525 - val_accuracy: 0.9920 - val_precision: 0.9927 - val_recall: 0.9916 - val_auc: 0.9995 - val_f1_score: 0.9922 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0402 - accuracy: 0.9956 - precision: 0.9963 - recall: 0.9947 - auc: 0.9999 - f1_score: 0.9955 - val_loss: 0.0508 - val_accuracy: 0.9909 - val_precision: 0.9917 - val_recall: 0.9901 - val_auc: 0.9997 - val_f1_score: 0.9909 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0388 - accuracy: 0.9958 - precision: 0.9965 - recall: 0.9950 - auc: 0.9999 - f1_score: 0.9957 - val_loss: 0.0702 - val_accuracy: 0.9869 - val_precision: 0.9885 - val_recall: 0.9849 - val_auc: 0.9992 - val_f1_score: 0.9867 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 6: 0.9868749976158142
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0581 - accuracy: 0.9915 - precision: 0.9915 - recall: 0.9905 - auc: 0.9997 - f1_score: 0.9910
# Test Accuracy for trial 6: 0.9915000200271606
# Model saved as models/diff_seeds/CNN6.h5
# Trial 7
# Epoch 1/15
# 938/938 - 9s - loss: 0.3278 - accuracy: 0.9370 - precision: 0.9635 - recall: 0.9175 - auc: 0.9965 - f1_score: 0.9399 - val_loss: 0.1548 - val_accuracy: 0.9803 - val_precision: 0.9827 - val_recall: 0.9784 - val_auc: 0.9994 - val_f1_score: 0.9805 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.1394 - accuracy: 0.9807 - precision: 0.9843 - recall: 0.9774 - auc: 0.9992 - f1_score: 0.9809 - val_loss: 0.1009 - val_accuracy: 0.9870 - val_precision: 0.9890 - val_recall: 0.9854 - val_auc: 0.9996 - val_f1_score: 0.9872 - 7s/epoch - 8ms/step
# Epoch 3/15
# 938/938 - 7s - loss: 0.0984 - accuracy: 0.9850 - precision: 0.9879 - recall: 0.9824 - auc: 0.9995 - f1_score: 0.9851 - val_loss: 0.0742 - val_accuracy: 0.9887 - val_precision: 0.9907 - val_recall: 0.9868 - val_auc: 0.9999 - val_f1_score: 0.9887 - 7s/epoch - 8ms/step
# Epoch 4/15
# 938/938 - 7s - loss: 0.0786 - accuracy: 0.9882 - precision: 0.9903 - recall: 0.9859 - auc: 0.9997 - f1_score: 0.9881 - val_loss: 0.0675 - val_accuracy: 0.9908 - val_precision: 0.9918 - val_recall: 0.9887 - val_auc: 0.9997 - val_f1_score: 0.9903 - 7s/epoch - 8ms/step
# Epoch 5/15
# 938/938 - 7s - loss: 0.0718 - accuracy: 0.9897 - precision: 0.9914 - recall: 0.9874 - auc: 0.9996 - f1_score: 0.9894 - val_loss: 0.0705 - val_accuracy: 0.9877 - val_precision: 0.9901 - val_recall: 0.9858 - val_auc: 0.9998 - val_f1_score: 0.9879 - 7s/epoch - 8ms/step
# Epoch 6/15
# 938/938 - 7s - loss: 0.0654 - accuracy: 0.9900 - precision: 0.9919 - recall: 0.9885 - auc: 0.9998 - f1_score: 0.9902 - val_loss: 0.0651 - val_accuracy: 0.9890 - val_precision: 0.9911 - val_recall: 0.9875 - val_auc: 0.9999 - val_f1_score: 0.9893 - 7s/epoch - 8ms/step
# Epoch 7/15
# 938/938 - 7s - loss: 0.0597 - accuracy: 0.9918 - precision: 0.9930 - recall: 0.9903 - auc: 0.9998 - f1_score: 0.9917 - val_loss: 0.0599 - val_accuracy: 0.9893 - val_precision: 0.9911 - val_recall: 0.9884 - val_auc: 0.9997 - val_f1_score: 0.9897 - 7s/epoch - 8ms/step
# Epoch 8/15
# 938/938 - 7s - loss: 0.0555 - accuracy: 0.9930 - precision: 0.9942 - recall: 0.9914 - auc: 0.9998 - f1_score: 0.9928 - val_loss: 0.0535 - val_accuracy: 0.9911 - val_precision: 0.9925 - val_recall: 0.9902 - val_auc: 0.9998 - val_f1_score: 0.9914 - 7s/epoch - 8ms/step
# Epoch 9/15
# 938/938 - 7s - loss: 0.0535 - accuracy: 0.9925 - precision: 0.9937 - recall: 0.9911 - auc: 0.9999 - f1_score: 0.9923 - val_loss: 0.0519 - val_accuracy: 0.9924 - val_precision: 0.9939 - val_recall: 0.9912 - val_auc: 0.9998 - val_f1_score: 0.9926 - 7s/epoch - 8ms/step
# Epoch 10/15
# 938/938 - 7s - loss: 0.0500 - accuracy: 0.9939 - precision: 0.9948 - recall: 0.9926 - auc: 0.9999 - f1_score: 0.9937 - val_loss: 0.0530 - val_accuracy: 0.9914 - val_precision: 0.9929 - val_recall: 0.9906 - val_auc: 0.9998 - val_f1_score: 0.9917 - 7s/epoch - 8ms/step
# Epoch 11/15
# 938/938 - 7s - loss: 0.0465 - accuracy: 0.9942 - precision: 0.9951 - recall: 0.9933 - auc: 0.9999 - f1_score: 0.9942 - val_loss: 0.0554 - val_accuracy: 0.9906 - val_precision: 0.9921 - val_recall: 0.9894 - val_auc: 0.9997 - val_f1_score: 0.9907 - 7s/epoch - 8ms/step
# Epoch 12/15
# 938/938 - 7s - loss: 0.0443 - accuracy: 0.9946 - precision: 0.9955 - recall: 0.9938 - auc: 0.9999 - f1_score: 0.9946 - val_loss: 0.0572 - val_accuracy: 0.9915 - val_precision: 0.9927 - val_recall: 0.9904 - val_auc: 0.9997 - val_f1_score: 0.9916 - 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0419 - accuracy: 0.9955 - precision: 0.9960 - recall: 0.9944 - auc: 0.9999 - f1_score: 0.9952 - val_loss: 0.0476 - val_accuracy: 0.9924 - val_precision: 0.9936 - val_recall: 0.9919 - val_auc: 0.9998 - val_f1_score: 0.9927 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0409 - accuracy: 0.9953 - precision: 0.9959 - recall: 0.9943 - auc: 0.9999 - f1_score: 0.9951 - val_loss: 0.0538 - val_accuracy: 0.9909 - val_precision: 0.9917 - val_recall: 0.9893 - val_auc: 0.9996 - val_f1_score: 0.9905 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0385 - accuracy: 0.9963 - precision: 0.9967 - recall: 0.9955 - auc: 0.9999 - f1_score: 0.9961 - val_loss: 0.0442 - val_accuracy: 0.9934 - val_precision: 0.9940 - val_recall: 0.9925 - val_auc: 0.9998 - val_f1_score: 0.9932 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 7: 0.9933750033378601
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9935 - auc: 0.9994 - f1_score: 0.9947
# Test Accuracy for trial 7: 0.9959999918937683
# Model saved as models/diff_seeds/CNN7.h5
# Trial 8
# Epoch 1/15
# 938/938 - 9s - loss: 0.3370 - accuracy: 0.9347 - precision: 0.9638 - recall: 0.9128 - auc: 0.9963 - f1_score: 0.9376 - val_loss: 0.1493 - val_accuracy: 0.9816 - val_precision: 0.9852 - val_recall: 0.9787 - val_auc: 0.9995 - val_f1_score: 0.9819 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.1408 - accuracy: 0.9803 - precision: 0.9845 - recall: 0.9767 - auc: 0.9992 - f1_score: 0.9806 - val_loss: 0.0997 - val_accuracy: 0.9861 - val_precision: 0.9889 - val_recall: 0.9839 - val_auc: 0.9995 - val_f1_score: 0.9864 - 7s/epoch - 8ms/step
# Epoch 3/15
# 938/938 - 7s - loss: 0.0992 - accuracy: 0.9845 - precision: 0.9875 - recall: 0.9819 - auc: 0.9995 - f1_score: 0.9847 - val_loss: 0.0904 - val_accuracy: 0.9851 - val_precision: 0.9884 - val_recall: 0.9822 - val_auc: 0.9993 - val_f1_score: 0.9853 - 7s/epoch - 8ms/step
# Epoch 4/15
# 938/938 - 7s - loss: 0.0805 - accuracy: 0.9877 - precision: 0.9895 - recall: 0.9852 - auc: 0.9996 - f1_score: 0.9874 - val_loss: 0.0675 - val_accuracy: 0.9900 - val_precision: 0.9920 - val_recall: 0.9884 - val_auc: 0.9997 - val_f1_score: 0.9902 - 7s/epoch - 8ms/step
# Epoch 5/15
# 938/938 - 7s - loss: 0.0716 - accuracy: 0.9892 - precision: 0.9912 - recall: 0.9870 - auc: 0.9997 - f1_score: 0.9891 - val_loss: 0.0648 - val_accuracy: 0.9901 - val_precision: 0.9917 - val_recall: 0.9876 - val_auc: 0.9998 - val_f1_score: 0.9897 - 7s/epoch - 8ms/step
# Epoch 6/15
# 938/938 - 7s - loss: 0.0661 - accuracy: 0.9901 - precision: 0.9920 - recall: 0.9884 - auc: 0.9997 - f1_score: 0.9902 - val_loss: 0.0686 - val_accuracy: 0.9883 - val_precision: 0.9907 - val_recall: 0.9874 - val_auc: 0.9996 - val_f1_score: 0.9890 - 7s/epoch - 8ms/step
# Epoch 7/15
# 938/938 - 7s - loss: 0.0621 - accuracy: 0.9912 - precision: 0.9926 - recall: 0.9895 - auc: 0.9997 - f1_score: 0.9911 - val_loss: 0.0706 - val_accuracy: 0.9883 - val_precision: 0.9897 - val_recall: 0.9849 - val_auc: 0.9997 - val_f1_score: 0.9873 - 7s/epoch - 8ms/step
# Epoch 8/15
# 938/938 - 7s - loss: 0.0587 - accuracy: 0.9916 - precision: 0.9933 - recall: 0.9900 - auc: 0.9998 - f1_score: 0.9916 - val_loss: 0.0544 - val_accuracy: 0.9916 - val_precision: 0.9929 - val_recall: 0.9901 - val_auc: 0.9998 - val_f1_score: 0.9915 - 7s/epoch - 8ms/step
# Epoch 9/15
# 938/938 - 7s - loss: 0.0537 - accuracy: 0.9928 - precision: 0.9944 - recall: 0.9917 - auc: 0.9998 - f1_score: 0.9930 - val_loss: 0.0658 - val_accuracy: 0.9895 - val_precision: 0.9906 - val_recall: 0.9879 - val_auc: 0.9995 - val_f1_score: 0.9892 - 7s/epoch - 8ms/step
# Epoch 10/15
# 938/938 - 7s - loss: 0.0512 - accuracy: 0.9933 - precision: 0.9942 - recall: 0.9921 - auc: 0.9998 - f1_score: 0.9931 - val_loss: 0.0522 - val_accuracy: 0.9920 - val_precision: 0.9935 - val_recall: 0.9900 - val_auc: 0.9998 - val_f1_score: 0.9917 - 7s/epoch - 8ms/step
# Epoch 11/15
# 938/938 - 7s - loss: 0.0472 - accuracy: 0.9944 - precision: 0.9955 - recall: 0.9933 - auc: 0.9999 - f1_score: 0.9944 - val_loss: 0.0511 - val_accuracy: 0.9919 - val_precision: 0.9927 - val_recall: 0.9910 - val_auc: 0.9997 - val_f1_score: 0.9919 - 7s/epoch - 8ms/step
# Epoch 12/15
# 938/938 - 7s - loss: 0.0452 - accuracy: 0.9947 - precision: 0.9954 - recall: 0.9937 - auc: 0.9999 - f1_score: 0.9945 - val_loss: 0.0542 - val_accuracy: 0.9896 - val_precision: 0.9917 - val_recall: 0.9886 - val_auc: 0.9998 - val_f1_score: 0.9902 - 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0433 - accuracy: 0.9950 - precision: 0.9959 - recall: 0.9941 - auc: 0.9999 - f1_score: 0.9950 - val_loss: 0.0695 - val_accuracy: 0.9860 - val_precision: 0.9883 - val_recall: 0.9843 - val_auc: 0.9992 - val_f1_score: 0.9863 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0427 - accuracy: 0.9949 - precision: 0.9956 - recall: 0.9941 - auc: 0.9999 - f1_score: 0.9949 - val_loss: 0.0598 - val_accuracy: 0.9891 - val_precision: 0.9899 - val_recall: 0.9879 - val_auc: 0.9996 - val_f1_score: 0.9889 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0390 - accuracy: 0.9958 - precision: 0.9964 - recall: 0.9950 - auc: 0.9999 - f1_score: 0.9957 - val_loss: 0.0509 - val_accuracy: 0.9916 - val_precision: 0.9926 - val_recall: 0.9894 - val_auc: 0.9998 - val_f1_score: 0.9910 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 8: 0.9916250109672546
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9955 - precision: 0.9955 - recall: 0.9955 - auc: 0.9994 - f1_score: 0.9955
# Test Accuracy for trial 8: 0.9955000281333923
# Model saved as models/diff_seeds/CNN8.h5
# Trial 9
# Epoch 1/15
# 938/938 - 9s - loss: 0.3534 - accuracy: 0.9301 - precision: 0.9600 - recall: 0.9071 - auc: 0.9958 - f1_score: 0.9328 - val_loss: 0.1525 - val_accuracy: 0.9821 - val_precision: 0.9850 - val_recall: 0.9797 - val_auc: 0.9994 - val_f1_score: 0.9824 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.1437 - accuracy: 0.9805 - precision: 0.9844 - recall: 0.9769 - auc: 0.9992 - f1_score: 0.9806 - val_loss: 0.0963 - val_accuracy: 0.9874 - val_precision: 0.9900 - val_recall: 0.9866 - val_auc: 0.9997 - val_f1_score: 0.9883 - 7s/epoch - 8ms/step
# Epoch 3/15
# 938/938 - 7s - loss: 0.0991 - accuracy: 0.9855 - precision: 0.9882 - recall: 0.9826 - auc: 0.9995 - f1_score: 0.9854 - val_loss: 0.0770 - val_accuracy: 0.9890 - val_precision: 0.9908 - val_recall: 0.9870 - val_auc: 0.9998 - val_f1_score: 0.9889 - 7s/epoch - 8ms/step
# Epoch 4/15
# 938/938 - 7s - loss: 0.0811 - accuracy: 0.9876 - precision: 0.9898 - recall: 0.9851 - auc: 0.9996 - f1_score: 0.9875 - val_loss: 0.0689 - val_accuracy: 0.9894 - val_precision: 0.9906 - val_recall: 0.9881 - val_auc: 0.9997 - val_f1_score: 0.9894 - 7s/epoch - 8ms/step
# Epoch 5/15
# 938/938 - 7s - loss: 0.0714 - accuracy: 0.9889 - precision: 0.9909 - recall: 0.9869 - auc: 0.9997 - f1_score: 0.9889 - val_loss: 0.0613 - val_accuracy: 0.9924 - val_precision: 0.9936 - val_recall: 0.9902 - val_auc: 0.9997 - val_f1_score: 0.9919 - 7s/epoch - 8ms/step
# Epoch 6/15
# 938/938 - 7s - loss: 0.0663 - accuracy: 0.9907 - precision: 0.9921 - recall: 0.9885 - auc: 0.9997 - f1_score: 0.9903 - val_loss: 0.0614 - val_accuracy: 0.9908 - val_precision: 0.9927 - val_recall: 0.9893 - val_auc: 0.9996 - val_f1_score: 0.9910 - 7s/epoch - 8ms/step
# Epoch 7/15
# 938/938 - 7s - loss: 0.0612 - accuracy: 0.9913 - precision: 0.9930 - recall: 0.9897 - auc: 0.9998 - f1_score: 0.9913 - val_loss: 0.0628 - val_accuracy: 0.9902 - val_precision: 0.9912 - val_recall: 0.9883 - val_auc: 0.9997 - val_f1_score: 0.9897 - 7s/epoch - 8ms/step
# Epoch 8/15
# 938/938 - 7s - loss: 0.0590 - accuracy: 0.9916 - precision: 0.9928 - recall: 0.9902 - auc: 0.9998 - f1_score: 0.9915 - val_loss: 0.0632 - val_accuracy: 0.9898 - val_precision: 0.9910 - val_recall: 0.9881 - val_auc: 0.9996 - val_f1_score: 0.9895 - 7s/epoch - 8ms/step
# Epoch 9/15
# 938/938 - 7s - loss: 0.0538 - accuracy: 0.9929 - precision: 0.9942 - recall: 0.9911 - auc: 0.9998 - f1_score: 0.9927 - val_loss: 0.0638 - val_accuracy: 0.9893 - val_precision: 0.9901 - val_recall: 0.9879 - val_auc: 0.9997 - val_f1_score: 0.9890 - 7s/epoch - 8ms/step
# Epoch 10/15
# 938/938 - 7s - loss: 0.0509 - accuracy: 0.9935 - precision: 0.9946 - recall: 0.9922 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0531 - val_accuracy: 0.9915 - val_precision: 0.9930 - val_recall: 0.9901 - val_auc: 0.9999 - val_f1_score: 0.9916 - 7s/epoch - 8ms/step
# Epoch 11/15
# 938/938 - 7s - loss: 0.0474 - accuracy: 0.9942 - precision: 0.9953 - recall: 0.9932 - auc: 0.9999 - f1_score: 0.9943 - val_loss: 0.0577 - val_accuracy: 0.9908 - val_precision: 0.9919 - val_recall: 0.9899 - val_auc: 0.9996 - val_f1_score: 0.9909 - 7s/epoch - 8ms/step
# Epoch 12/15
# 938/938 - 7s - loss: 0.0458 - accuracy: 0.9940 - precision: 0.9950 - recall: 0.9931 - auc: 0.9999 - f1_score: 0.9940 - val_loss: 0.0604 - val_accuracy: 0.9899 - val_precision: 0.9905 - val_recall: 0.9891 - val_auc: 0.9995 - val_f1_score: 0.9898 - 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0462 - accuracy: 0.9941 - precision: 0.9948 - recall: 0.9931 - auc: 0.9998 - f1_score: 0.9939 - val_loss: 0.0510 - val_accuracy: 0.9921 - val_precision: 0.9925 - val_recall: 0.9918 - val_auc: 0.9996 - val_f1_score: 0.9921 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0417 - accuracy: 0.9951 - precision: 0.9959 - recall: 0.9944 - auc: 0.9999 - f1_score: 0.9952 - val_loss: 0.0504 - val_accuracy: 0.9929 - val_precision: 0.9942 - val_recall: 0.9919 - val_auc: 0.9994 - val_f1_score: 0.9931 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0377 - accuracy: 0.9962 - precision: 0.9968 - recall: 0.9955 - auc: 0.9999 - f1_score: 0.9961 - val_loss: 0.0526 - val_accuracy: 0.9904 - val_precision: 0.9923 - val_recall: 0.9889 - val_auc: 0.9996 - val_f1_score: 0.9906 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 9: 0.9903749823570251
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9925 - precision: 0.9930 - recall: 0.9920 - auc: 0.9994 - f1_score: 0.9925
# Test Accuracy for trial 9: 0.9925000071525574
# Model saved as models/diff_seeds/CNN9.h5
# Trial 10
# Epoch 1/15
# 938/938 - 9s - loss: 0.3293 - accuracy: 0.9368 - precision: 0.9639 - recall: 0.9170 - auc: 0.9964 - f1_score: 0.9398 - val_loss: 0.1792 - val_accuracy: 0.9739 - val_precision: 0.9770 - val_recall: 0.9699 - val_auc: 0.9987 - val_f1_score: 0.9734 - 9s/epoch - 10ms/step
# Epoch 2/15
# 938/938 - 7s - loss: 0.1389 - accuracy: 0.9805 - precision: 0.9843 - recall: 0.9768 - auc: 0.9991 - f1_score: 0.9805 - val_loss: 0.1116 - val_accuracy: 0.9825 - val_precision: 0.9855 - val_recall: 0.9799 - val_auc: 0.9995 - val_f1_score: 0.9827 - 7s/epoch - 8ms/step
# Epoch 3/15
# 938/938 - 7s - loss: 0.0968 - accuracy: 0.9859 - precision: 0.9884 - recall: 0.9834 - auc: 0.9995 - f1_score: 0.9859 - val_loss: 0.0817 - val_accuracy: 0.9869 - val_precision: 0.9894 - val_recall: 0.9843 - val_auc: 0.9997 - val_f1_score: 0.9868 - 7s/epoch - 8ms/step
# Epoch 4/15
# 938/938 - 7s - loss: 0.0803 - accuracy: 0.9876 - precision: 0.9896 - recall: 0.9851 - auc: 0.9996 - f1_score: 0.9874 - val_loss: 0.0833 - val_accuracy: 0.9854 - val_precision: 0.9891 - val_recall: 0.9830 - val_auc: 0.9994 - val_f1_score: 0.9860 - 7s/epoch - 8ms/step
# Epoch 5/15
# 938/938 - 7s - loss: 0.0717 - accuracy: 0.9896 - precision: 0.9915 - recall: 0.9872 - auc: 0.9996 - f1_score: 0.9894 - val_loss: 0.0621 - val_accuracy: 0.9911 - val_precision: 0.9921 - val_recall: 0.9896 - val_auc: 0.9997 - val_f1_score: 0.9909 - 7s/epoch - 8ms/step
# Epoch 6/15
# 938/938 - 7s - loss: 0.0645 - accuracy: 0.9906 - precision: 0.9925 - recall: 0.9891 - auc: 0.9997 - f1_score: 0.9908 - val_loss: 0.0712 - val_accuracy: 0.9872 - val_precision: 0.9887 - val_recall: 0.9855 - val_auc: 0.9995 - val_f1_score: 0.9871 - 7s/epoch - 8ms/step
# Epoch 7/15
# 938/938 - 7s - loss: 0.0603 - accuracy: 0.9915 - precision: 0.9929 - recall: 0.9898 - auc: 0.9998 - f1_score: 0.9914 - val_loss: 0.0637 - val_accuracy: 0.9898 - val_precision: 0.9917 - val_recall: 0.9874 - val_auc: 0.9996 - val_f1_score: 0.9895 - 7s/epoch - 8ms/step
# Epoch 8/15
# 938/938 - 7s - loss: 0.0561 - accuracy: 0.9923 - precision: 0.9937 - recall: 0.9908 - auc: 0.9997 - f1_score: 0.9923 - val_loss: 0.0621 - val_accuracy: 0.9893 - val_precision: 0.9912 - val_recall: 0.9881 - val_auc: 0.9997 - val_f1_score: 0.9897 - 7s/epoch - 8ms/step
# Epoch 9/15
# 938/938 - 7s - loss: 0.0501 - accuracy: 0.9940 - precision: 0.9948 - recall: 0.9927 - auc: 0.9998 - f1_score: 0.9938 - val_loss: 0.0542 - val_accuracy: 0.9920 - val_precision: 0.9937 - val_recall: 0.9905 - val_auc: 0.9999 - val_f1_score: 0.9921 - 7s/epoch - 8ms/step
# Epoch 10/15
# 938/938 - 7s - loss: 0.0487 - accuracy: 0.9938 - precision: 0.9951 - recall: 0.9928 - auc: 0.9999 - f1_score: 0.9939 - val_loss: 0.0634 - val_accuracy: 0.9875 - val_precision: 0.9896 - val_recall: 0.9869 - val_auc: 0.9995 - val_f1_score: 0.9882 - 7s/epoch - 8ms/step
# Epoch 11/15
# 938/938 - 7s - loss: 0.0475 - accuracy: 0.9939 - precision: 0.9949 - recall: 0.9928 - auc: 0.9998 - f1_score: 0.9938 - val_loss: 0.0608 - val_accuracy: 0.9889 - val_precision: 0.9900 - val_recall: 0.9875 - val_auc: 0.9993 - val_f1_score: 0.9887 - 7s/epoch - 8ms/step
# Epoch 12/15
# 938/938 - 7s - loss: 0.0451 - accuracy: 0.9948 - precision: 0.9957 - recall: 0.9934 - auc: 0.9999 - f1_score: 0.9946 - val_loss: 0.0570 - val_accuracy: 0.9904 - val_precision: 0.9920 - val_recall: 0.9889 - val_auc: 0.9996 - val_f1_score: 0.9904 - 7s/epoch - 8ms/step
# Epoch 13/15
# 938/938 - 7s - loss: 0.0417 - accuracy: 0.9955 - precision: 0.9960 - recall: 0.9945 - auc: 0.9999 - f1_score: 0.9953 - val_loss: 0.0537 - val_accuracy: 0.9901 - val_precision: 0.9919 - val_recall: 0.9889 - val_auc: 0.9997 - val_f1_score: 0.9904 - 7s/epoch - 8ms/step
# Epoch 14/15
# 938/938 - 7s - loss: 0.0398 - accuracy: 0.9955 - precision: 0.9962 - recall: 0.9948 - auc: 0.9999 - f1_score: 0.9955 - val_loss: 0.0480 - val_accuracy: 0.9912 - val_precision: 0.9927 - val_recall: 0.9904 - val_auc: 0.9998 - val_f1_score: 0.9916 - 7s/epoch - 8ms/step
# Epoch 15/15
# 938/938 - 7s - loss: 0.0404 - accuracy: 0.9952 - precision: 0.9958 - recall: 0.9943 - auc: 1.0000 - f1_score: 0.9951 - val_loss: 0.0509 - val_accuracy: 0.9915 - val_precision: 0.9931 - val_recall: 0.9909 - val_auc: 0.9996 - val_f1_score: 0.9920 - 7s/epoch - 8ms/step
# Validation Accuracy for trial 10: 0.9915000200271606
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9935 - precision: 0.9955 - recall: 0.9935 - auc: 0.9997 - f1_score: 0.9945
# Test Accuracy for trial 10: 0.9934999942779541
# Model saved as models/diff_seeds/CNN10.h5

# %%
for result in results:
    print(f"Trial {result['trial']}: Seed {result['seed']} - Validation Accuracy: {result['val_acc']} ")
# Out:
# Trial 1: Seed 0 - Validation Accuracy: 0.9917730689048767
# Trial 2: Seed 1 - Validation Accuracy: 0.9907907843589783
# Trial 3: Seed 2 - Validation Accuracy: 0.9917730689048767
# Trial 4: Seed 3 - Validation Accuracy: 0.9914047122001648
# Trial 5: Seed 4 - Validation Accuracy: 0.9899312257766724
# Trial 6: Seed 5 - Validation Accuracy: 0.9902995824813843
# Trial 7: Seed 6 - Validation Accuracy: 0.9916502833366394
# Trial 8: Seed 7 - Validation Accuracy: 0.990667998790741
# Trial 9: Seed 8 - Validation Accuracy: 0.991895854473114
# Trial 10: Seed 9 - Validation Accuracy: 0.9907907843589783
